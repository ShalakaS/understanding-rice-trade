# %%
import pandas as pd
import requests
pd.set_option('display.float_format', lambda x: '%.2f' % x)
import camelot
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt
from pywaffle import Waffle

# %%
df = pd.read_csv('FAOSTAT.csv')
df
# Out:
#        Domain Code                        Domain  Area Code (M49)  \
# 0              QCL  Crops and livestock products                4
# 1              QCL  Crops and livestock products                4
# 2              QCL  Crops and livestock products                4
# 3              QCL  Crops and livestock products                4
# 4              QCL  Crops and livestock products                4
# ...            ...                           ...              ...
# 124849         QCL  Crops and livestock products              716
# 124850         QCL  Crops and livestock products              716
# 124851         QCL  Crops and livestock products              716
# 124852         QCL  Crops and livestock products              716
# 124853         QCL  Crops and livestock products              716
#
#                Area  Element Code     Element Item Code (CPC)  \
# 0       Afghanistan          5510  Production           01371
# ...

# %%
df[df.Item == "Rice"].groupby('Area').Value.mean().to_csv('final_rice.csv')

# %%
rice_df = pd.read_csv('final_rice.csv')
rice_df
# Out:
#                                    Area       Value
# 0                           Afghanistan   450806.97
# 1                               Albania        0.00
# 2                               Algeria      310.98
# 3                                Angola    22254.82
# 4                             Argentina  1453332.45
# ..                                  ...         ...
# 139                          Uzbekistan   325305.91
# 140  Venezuela (Bolivarian Republic of)   790505.81
# 141                            Viet Nam 43661360.70
# 142                              Zambia    41171.17
# 143                            Zimbabwe     1342.72
#
# [144 rows x 2 columns]

# %%
rice_df.reset_index(drop=True)
# Out:
#                                    Area       Value
# 0                           Afghanistan   450806.97
# 1                               Albania        0.00
# 2                               Algeria      310.98
# 3                                Angola    22254.82
# 4                             Argentina  1453332.45
# ..                                  ...         ...
# 139                          Uzbekistan   325305.91
# 140  Venezuela (Bolivarian Republic of)   790505.81
# 141                            Viet Nam 43661360.70
# 142                              Zambia    41171.17
# 143                            Zimbabwe     1342.72
#
# [144 rows x 2 columns]

# %%
rice_df.Value = rice_df.Value.round(2)
rice_df.Value
# Out:
# 0       450806.97
# 1            0.00
# 2          310.98
# 3        22254.82
# 4      1453332.45
#           ...
# 139     325305.91
# 140     790505.81
# 141   43661360.70
# 142      41171.17
# 143       1342.72
# Name: Value, Length: 144, dtype: float64

# %%
rice_df.sort_values(by='Value', ascending=False).head(10).to_csv('final_rice.csv', index=False)

# %%
pd.read_csv('final_rice.csv')
# Out:
#               Area        Value
# 0  China, mainland 208883117.09
# 1            India 168765784.09
# 2        Indonesia  57300096.66
# 3       Bangladesh  52883973.82
# 4         Viet Nam  43661360.70
# 5         Thailand  32983866.09
# 6          Myanmar  26429975.91
# 7      Philippines  18573928.16
# 8           Brazil  11754713.36
# 9            Japan  10821954.55
